# %% [markdown]
# # EMDAT

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2

# %%
from src.datasources import emdat

# %%
emdat_df = emdat.load_emdat()

# %%
emdat_df
# Out:
#            DisNo. Historic Classification Key Disaster Group  \
# 0   2003-0389-BFA       No    nat-hyd-flo-riv        Natural
# 1   2006-0445-BFA       No    nat-hyd-flo-fla        Natural
# 2   2006-0507-BFA       No    nat-hyd-flo-riv        Natural
# 3   2007-0305-BFA       No    nat-hyd-flo-riv        Natural
# 4   2008-0360-BFA       No    nat-hyd-flo-fla        Natural
# 5   2008-0379-BFA       No    nat-hyd-flo-riv        Natural
# 6   2009-0243-BFA       No    nat-hyd-flo-riv        Natural
# 7   2009-0444-BFA       No    nat-hyd-flo-riv        Natural
# 8   2010-0300-BFA       No    nat-hyd-flo-riv        Natural
# 9   2012-0337-BFA       No    nat-hyd-flo-riv        Natural
# 10  2013-0330-BFA       No    nat-hyd-flo-riv        Natural
# 11  2015-0346-BFA       No    nat-hyd-flo-riv        Natural
# 12  2016-0287-BFA       No    nat-hyd-flo-riv        Natural
# 13  2017-0368-BFA       No    nat-hyd-flo-flo        Natural
# ...
